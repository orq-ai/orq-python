# %%
import os
from orquesta_sdk import OrquestaClient, OrquestaClientOptions

api_key = os.environ.get("ORQUESTA_API_KEY",
                         "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ3b3Jrc3BhY2VJZCI6IjhkMjZjODdkLTU1YzUtNDM0My1hYmI0LWM0YTAxYjFhNDVhMSIsImlhdCI6MTY5NzU3NTYzMTE5N30.By3LONyOaIaIXxVEApJQJhHmQMPCUdBVJtI088SZz6Q")

options = OrquestaClientOptions(
    api_key=api_key
)

client = OrquestaClient(options)
# Out:
# /Users/tony/Projects/orquesta/orquesta-python/venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from orquesta_sdk.remoteconfigs import OrquestaRemoteConfigRequest

request = OrquestaRemoteConfigRequest(
    key="api-rate-limits",
    default_value=50,
    context={
        "environments": [
            "production"
        ],
        "customer-tier": [
            "enterprise"
        ],
        "account-id": "contract456",
        "countries": [
            "ITA"
        ]
    },
    metadata={"custom-field-name": "custom-metadata-value"}
)

config = client.remoteconfigs.query(
    request
)

# %%
from orquesta_sdk.prompts import OrquestaPromptRequest

request = OrquestaPromptRequest(
    key="chat-demo-endpoint",
    context={
        "user-segment": [],
        "environments": [],
        "user-role": [],
        "countries": []
    },
    metadata={"custom-field-name": "custom-metadata-value"}
)

prompt = client.prompts.query(
    request
)

print(prompt.value)

# %%
from orquesta_sdk.endpoints import OrquestaEndpointRequest

request = OrquestaEndpointRequest(
    key="chat-multimodel",
    context={
        "user-segment": [],
        "environments": [],
        "user-role": [],
        "countries": []
    },
    metadata={"custom-field-name": "custom-metadata-value"}
)

prompt = client.endpoints.query(
    request
)

print(prompt.content)

# %%
from orquesta_sdk.endpoints import OrquestaEndpointRequest

request = OrquestaEndpointRequest(
    key="chat-multimodel",
    context={
        "user-segment": [],
        "environments": [],
        "user-role": [],
        "countries": []
    },
    metadata={"custom-field-name": "custom-metadata-value"}
)

stream = client.endpoints.stream(
    request
)

def handle_next(chunk):
    print(f"Received {chunk.content}")


def handle_error(e):
    print(f"Error Occurred: {e}")


def handle_completed():
    print("Done!")


stream.subscribe(
    on_next=handle_next,
    on_error=handle_error,
    on_completed=handle_completed,
)
# Out:
# Received
# Received You
# Received  can
# Received  check
# Received  the
# Received  status
# Received  of
# Received  your
# Received  tax
# Received  refund
# Received  by
# Received  visiting
# Received  the
# Received  "
# Received Where
# Received 's
# Received  My
# Received  Ref
# Received und
# Received ?"
# Received  tool
# Received  on
# Received  the
# Received  official
# Received  website
# Received  of
# Received  the
# Received  Internal
# Received  Revenue
# Received  Service
# Received  (
# Received IRS
# Received ).
# Received  Here
# Received  are
# Received  the
# Received  steps
# Received  to
# Received  follow
# Received :
#
#
# Received 1
# Received .
# Received  Go
# Received  to
# Received  the
# Received  IRS
# Received  website
# Received  at
# Received  www
# Received .
# Received irs
# Received .gov
# Received .
#
# Received 2
# Received .
# Received  Click
# Received  on
# Received  the
# Received  "
# Received Ref
# Received unds
# Received "
# Received  tab
# Received .
#
# Received 3
# Received .
# Received  Select
# Received  the
# Received  "
# Received Where
# Received 's
# Received  My
# Received  Ref
# Received und
# Received ?"
# Received  option
# Received .
#
# Received 4
# Received .
# Received  You
# Received  will
# Received  need
# Received  to
# Received  provide
# Received  your
# Received  Social
# Received  Security
# Received  number
# Received  or
# Received  Individual
# Received  Tax
# Received payer
# Received  Identification
# Received  Number
# Received  (
# Received IT
# Received IN
# Received ),
# Received  your
# Received  filing
# Received  status
# Received ,
# Received  and
# Received  the
# Received  exact
# Received  refund
# Received  amount
# Received  as
# Received  shown
# Received  on
# Received  your
# Received  tax
# Received  return
# Received .
#
# Received 5
# Received .
# Received  Click
# Received  on
# Received  the
# Received  "
# Received Submit
# Received "
# Received  button
# Received  to
# Received  view
# Received  the
# Received  status
# Received  of
# Received  your
# Received  refund
# Received .
#
#
# Received Please
# Received  note
# Received  that
# Received  it
# Received  may
# Received  take
# Received  some
# Received  time
# Received  for
# Received  your
# Received  refund
# Received  status
# Received  to
# Received  be
# Received  updated
# Received ,
# Received  so
# Received  it
# Received 's
# Received  a
# Received  good
# Received  idea
# Received  to
# Received  check
# Received  periodically
# Received .
# Received
# Received
