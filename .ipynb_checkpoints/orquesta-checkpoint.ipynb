# %%
import os
from orquesta_sdk import OrquestaClient, OrquestaClientOptions

api_key = os.environ.get("ORQUESTA_API_KEY",
                         "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ3b3Jrc3BhY2VJZCI6IjhkMjZjODdkLTU1YzUtNDM0My1hYmI0LWM0YTAxYjFhNDVhMSIsImlhdCI6MTY5NzU3NTYzMTE5N30.By3LONyOaIaIXxVEApJQJhHmQMPCUdBVJtI088SZz6Q")

options = OrquestaClientOptions(
    api_key=api_key
)

client = OrquestaClient(options)
# Out:
# /Users/tony/Projects/orquesta/orquesta-python/venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from orquesta_sdk.remoteconfigs import OrquestaRemoteConfigRequest

request = OrquestaRemoteConfigRequest(
    key="api-rate-limits",
    default_value=50,
    context={
        "environments": [
            "production"
        ],
        "customer-tier": [
            "enterprise"
        ],
        "account-id": "contract456",
        "countries": [
            "ITA"
        ]
    },
    metadata={"custom-field-name": "custom-metadata-value"}
)

config = client.remoteconfigs.query(
    request
)

# %%
from orquesta_sdk.prompts import OrquestaPromptRequest

request = OrquestaPromptRequest(
    key="chat-demo-endpoint",
    context={
        "user-segment": [],
        "environments": [],
        "user-role": [],
        "countries": []
    },
    metadata={"custom-field-name": "custom-metadata-value"}
)

prompt = client.prompts.query(
    request
)

print(prompt.value)

# %%
from orquesta_sdk.endpoints import OrquestaEndpointRequest

request = OrquestaEndpointRequest(
    key="chat-multimodel",
    context={
        "user-segment": [],
        "environments": [],
        "user-role": [],
        "countries": []
    },
    metadata={"custom-field-name": "custom-metadata-value"}
)

prompt = client.endpoints.query(
    request
)

print(prompt.content)

# %%
from orquesta_sdk.endpoints import OrquestaEndpointRequest

request = OrquestaEndpointRequest(
    key="chat-multimodel",
    context={
        "user-segment": [],
        "environments": [],
        "user-role": [],
        "countries": []
    },
    metadata={"custom-field-name": "custom-metadata-value"}
)

stream = client.endpoints.stream(
    request
)

def handle_next(chunk):
    print(f"Received {chunk.content}")


def handle_error(e):
    print(f"Error Occurred: {e}")


def handle_completed():
    print("Done!")


stream.subscribe(
    on_next=handle_next,
    on_error=handle_error,
    on_completed=handle_completed,
)
# Out:
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"You","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" can","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" check","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" status","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" of","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" your","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" tax","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" refund","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" by","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" visiting","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" \"","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"Where","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"'s","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" My","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" Ref","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"und","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"?\"","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" tool","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" on","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" official","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" website","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" of","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" Internal","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" Revenue","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" Service","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" (","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"IRS","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":").","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" Here","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" are","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" steps","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" to","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" follow","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":":\n\n","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"1","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" Go","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" to","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" IRS","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" website","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" at","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" www","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"irs","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".gov","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".\n","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"2","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" Click","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" on","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" \"","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"Ref","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"unds","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"\"","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" tab","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".\n","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"3","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" Select","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" \"","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"Where","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"'s","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" My","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" Ref","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"und","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"?\"","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" from","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" drop","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"-down","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" menu","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".\n","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"4","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" You","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" will","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" need","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" to","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" provide","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" your","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" Social","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" Security","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" number","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":",","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" filing","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" status","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":",","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" and","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" exact","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" refund","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" amount","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" as","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" shown","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" on","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" your","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" tax","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" return","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".\n","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"5","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" Click","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" on","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" \"","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"Submit","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"\"","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" button","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" to","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" view","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" status","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" of","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" your","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" refund","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".\n\n","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"Please","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" note","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" that","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" it","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" may","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" take","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" some","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" time","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" for","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" IRS","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" to","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" process","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" your","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" return","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" and","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" update","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" refund","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" status","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" Typically","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":",","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" you","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" can","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" check","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" the","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" status","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" within","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" ","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"24","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" hours","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" after","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" e","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"-f","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"iling","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" or","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" four","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" weeks","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" after","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" mailing","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" your","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" paper","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":" return","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":".","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"","is_final":false}
# Received data: {"trace_id":"3f9db018f4a946ec977ec7346a71e532","content":"","is_final":true}
# Received data: [DONE]
